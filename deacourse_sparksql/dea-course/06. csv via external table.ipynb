-- %%
%python
display(spark.read.csv('abfss://gizmobox@deacourseadlsa.dfs.core.windows.net/landing/external_data/payments/',inferSchema=True))

-- %%
DROP TABLE IF EXISTS dea_course_catalog_gizmobox.bronze.payments;
CREATE TABLE IF NOT EXISTS dea_course_catalog_gizmobox.bronze.payments
(payment_id INTEGER, order_id INT, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING)
USING CSV
OPTIONS (
    header = true,
    delimiter = ","
)
LOCATION 'abfss://gizmobox@deacourseadlsa.dfs.core.windows.net/landing/external_data/payments/'

-- %%
select * from dea_course_catalog_gizmobox.bronze.payments

-- %%
DESCRIBE EXTENDED dea_course_catalog_gizmobox.bronze.payments

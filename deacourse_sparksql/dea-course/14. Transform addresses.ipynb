-- %%
select * from dea_course_catalog_gizmobox.bronze.v_addresses

-- %%
select
  *
FROM
  (
    SELECT
      customer_id,
      address_type,
      address_line_1,
      city,
      state,
      postcode
    FROM
      dea_course_catalog_gizmobox.bronze.v_addresses v
  )
    PIVOT (
      MAX(address_line_1) AS address_line_1,
      MAX(city) AS city,
      MAX(state) AS state,
      MAX(postcode) AS postcode FOR address_type IN ('shipping', 'billing')
    )

-- %%
DROP TABLE IF EXISTS dea_course_catalog_gizmobox.silver.addresses;
CREATE TABLE dea_course_catalog_gizmobox.silver.addresses as
select
  *
FROM
  (
    SELECT
      customer_id,
      address_type,
      address_line_1,
      city,
      state,
      postcode
    FROM
      dea_course_catalog_gizmobox.bronze.v_addresses v
  )
    PIVOT (
      MAX(address_line_1) AS address_line_1,
      MAX(city) AS city,
      MAX(state) AS state,
      MAX(postcode) AS postcode FOR address_type IN ('shipping', 'billing')
    );

-- %%
select * from dea_course_catalog_gizmobox.silver.addresses

-- %%
DESCRIBE EXTENDED dea_course_catalog_gizmobox.silver.addresses

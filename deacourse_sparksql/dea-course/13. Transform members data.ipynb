-- %%
select 
TRIM(REPLACE(split(path,"/")[7],".png","")) as customer_id
,content
 from dea_course_catalog_gizmobox.bronze.v_memberships

-- %%
CREATE TABLE dea_course_catalog_gizmobox.silver.memberships 
AS 
select 
TRIM(REPLACE(split(path,"/")[7],".png","")) as customer_id
,content
 from dea_course_catalog_gizmobox.bronze.v_memberships

-- %%
SELECT * FROM dea_course_catalog_gizmobox.silver.memberships

-- %%
DESCRIBE EXTENDED dea_course_catalog_gizmobox.silver.memberships

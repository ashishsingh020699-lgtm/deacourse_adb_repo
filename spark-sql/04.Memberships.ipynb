-- %%
CREATE OR REPLACE VIEW dea_course_catalog_gizmobox.bronze.V_memberships
AS
select
  *
from
  binaryFile.`/Volumes/dea_course_catalog_gizmobox/landing/operational_data/memberships/*/*.png`

-- %%
select * from dea_course_catalog_gizmobox.bronze.v_memberships

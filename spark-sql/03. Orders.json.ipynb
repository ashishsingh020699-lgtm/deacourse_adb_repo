-- %%
select * from json.`/Volumes/dea_course_catalog_gizmobox/landing/operational_data/orders/`

-- %%
CREATE OR REPLACE VIEW dea_course_catalog_gizmobox.bronze.v_orders
AS
select
  _metadata.file_path,
  *
from
  text.`/Volumes/dea_course_catalog_gizmobox/landing/operational_data/orders/`

-- %%
select * from v_orders
